# %%
# !pip install pandas numpy matplotlib seaborn

# %%
data = {
    'Product': ['Laptop', 'Phone', 'Tablet', 'Laptop', 'Phone', 'Tablet'],
    'Region': ['North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': [50000, 30000, 20000, 45000, 32000, 22000],
    'Quantity': [5, 10, 7, 4, 12, 6]
}

df = pd.DataFrame(data)
df
# Out:
#   Product Region  Sales  Quantity
# 0  Laptop  North  50000         5
# 1   Phone  South  30000        10
# 2  Tablet   East  20000         7
# 3  Laptop   West  45000         4
# 4   Phone  North  32000        12
# 5  Tablet  South  22000         6

# %%
df.head()
# Out:
#   Product Region  Sales  Quantity
# 0  Laptop  North  50000         5
# 1   Phone  South  30000        10
# 2  Tablet   East  20000         7
# 3  Laptop   West  45000         4
# 4   Phone  North  32000        12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   6 non-null      object
#  1   Region    6 non-null      object
#  2   Sales     6 non-null      int64
#  3   Quantity  6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#               Sales   Quantity
# count      6.000000   6.000000
# mean   33166.666667   7.333333
# std    12106.472098   3.076795
# min    20000.000000   4.000000
# 25%    24000.000000   5.250000
# 50%    31000.000000   6.500000
# 75%    41750.000000   9.250000
# max    50000.000000  12.000000

# %%
df.isnull().sum()
# Out:
# Product     0
# Region      0
# Sales       0
# Quantity    0
# dtype: int64

# %%
product_sales = df.groupby('Product')['Sales'].sum()
product_sales
# Out:
# Product
# Laptop    95000
# Phone     62000
# Tablet    42000
# Name: Sales, dtype: int64

# %%
product_sales.plot(kind='bar')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.show()

# %%
plt.hist(df['Sales'], bins=5)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
sns.barplot(x='Region', y='Sales', data=df)
plt.title('Sales by Region')
plt.show()

# %%
print("Insights:")
print("- Laptops generate the highest revenue.")
print("- North and West regions perform better.")
print("- Sales are moderately distributed.")
# Out:
# Insights:
# - Laptops generate the highest revenue.
# - North and West regions perform better.
# - Sales are moderately distributed.
